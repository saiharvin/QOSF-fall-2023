# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %%
# Define the XOR input and target data
XOR_INPUT = np.array([[0, 0], [1, 0], [0, 1], [1, 1]], dtype=np.float32)
XOR_TARGET = np.array([[0], [1], [1], [0]], dtype=np.float32)

# %%
# Convert the NumPy arrays to PyTorch tensors
inputs = torch.from_numpy(XOR_INPUT).view(1, 4, 2)  # Add a batch and sequence dimension
targets = torch.from_numpy(XOR_TARGET).view(1, 4, 1)  # Add a batch and sequence dimension

# %%
# Define the RNN model for XOR
class XORRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(XORRNN, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.linear = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.rnn(x)
        out = self.linear(out)
        return out

# %%
# Create an instance of the XORRNN model
rnn_model = XORRNN(input_size=2, hidden_size=5, output_size=1)

# Define the loss function and the optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(rnn_model.parameters(), lr=0.01)

# Training the RNN for XOR
epochs = 100

# %%
for epoch in range(epochs):
    # Forward pass
    outputs = rnn_model(inputs)
    loss = criterion(outputs, targets)

    # Backward pass and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Print the loss every 1000 epochs
    if epoch % 10 == 0:
        print(f'Epoch {epoch}, Loss: {loss.item()}')
# Out:
# Epoch 0, Loss: 0.9615192413330078
# Epoch 10, Loss: 0.3550166189670563
# Epoch 20, Loss: 0.21109890937805176
# Epoch 30, Loss: 0.203890860080719
# Epoch 40, Loss: 0.1474422812461853
# Epoch 50, Loss: 0.08678492903709412
# Epoch 60, Loss: 0.0242239311337471
# Epoch 70, Loss: 0.008654740639030933
# Epoch 80, Loss: 0.0034228197764605284
# Epoch 90, Loss: 9.3805581855122e-05

# %%
# Testing the RNN on XOR data
with torch.no_grad():
    test_outputs = rnn_model(inputs)
    for i in range(len(XOR_INPUT)):
        input_data = XOR_INPUT[i]
        output = test_outputs[0, i, 0].item()
        target = XOR_TARGET[i, 0]
        print(f'Input: {input_data}, Output: {output}, Target: {target}')
# Out:
# Input: [0. 0.], Output: -0.02073618769645691, Target: 0.0
# Input: [1. 0.], Output: 0.9906268119812012, Target: 1.0
# Input: [0. 1.], Output: 0.9780938625335693, Target: 1.0
# Input: [1. 1.], Output: 0.013291195034980774, Target: 0.0
